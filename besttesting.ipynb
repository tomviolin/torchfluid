# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = pd.read_csv("masterdata.csv",header=None)

# %%
x
# Out:
#                                       0    1    2  3  4         5
# 0    datadir/20230313_012627/report.txt  100  100  1  1  0.000725
# 1    datadir/20230313_012637/report.txt  100  100  1  1  0.000448
# 2    datadir/20230313_012651/report.txt  100  100  1  1  0.000673
# 3    datadir/20230313_012701/report.txt  100  100  1  1  0.005833
# 4    datadir/20230313_012718/report.txt  100  100  1  1  0.000319
# ..                                  ...  ...  ... .. ..       ...
# 834  datadir/20230313_035746/report.txt  100  100  1  1  0.009435
# 835  datadir/20230313_035759/report.txt  100  100  1  1  0.000384
# 836  datadir/20230313_035810/report.txt  100  100  1  1  0.000427
# 837  datadir/20230313_035819/report.txt  100  100  1  1  0.014299
# 838  datadir/20230313_035832/report.txt  100  100  1  1  0.000675
#
# [839 rows x 6 columns]

# %%
idx=x[5].argsort()

# %%
idx
# Out:
# 0      826
# 1      786
# 2      153
# 3      447
# 4      353
#       ...
# 834    711
# 835     71
# 836    336
# 837    487
# 838     96
# Name: 5, Length: 839, dtype: int64

# %%
import os,sys

# %%
bestmodel = os.path.sep.join(x.iloc[0,0].split(os.path.sep)[0:2])+os.path.sep+"model_params.json"

# %%
more {bestmodel}

# %%
os.environ['MODEL_PARAMS']=bestmodel

# %%
run fluid.py
# Out:
# COMPUTING DEVICE: cuda:0
# {'ROUND': 1, 'MODEL_ID': 1001, 'INIT_LR': 0.01, 'BATCHSIZE': 1, 'NUM_EPOCHS': 100, 'NUM_META_EPOCS': 1, 'ITERS': 1.1, 'SCRAMBLE_SIZE': 1, 'LAYER': [{'NCHAN': 5, 'KSIZE': 3, 'LEAK': 0.5, 'DROPOUT': 0.1}, {'NCHAN': 1, 'KSIZE': 5, 'LEAK': 0.5, 'DROPOUT': 0.0}], 'LAYER_LAST': {'KSIZE': 1, 'LEAK': 0.0, 'DROPOUT': 0.2}}
# LOADING DATA
# ....................................................................................................100
# ....................................................................................................200
# ....................................................................................................300
# ....................................................................................................400
# ....................................................................................................500
# ....................................................................................................600
# ...

# %%
run fluid.py -r
# Out:
# COMPUTING DEVICE: cuda:0
# {'ROUND': 1, 'MODEL_ID': 1001, 'INIT_LR': 0.01, 'BATCHSIZE': 1, 'NUM_EPOCHS': 100, 'NUM_META_EPOCS': 1, 'ITERS': 1.1, 'SCRAMBLE_SIZE': 1, 'LAYER': [{'NCHAN': 5, 'KSIZE': 3, 'LEAK': 0.5, 'DROPOUT': 0.1}, {'NCHAN': 1, 'KSIZE': 5, 'LEAK': 0.5, 'DROPOUT': 0.0}], 'LAYER_LAST': {'KSIZE': 1, 'LEAK': 0.0, 'DROPOUT': 0.2}}
# LOADING DATA
# ....................................................................................................100
# ....................................................................................................200
# ....................................................................................................300
# ....................................................................................................400
# ....................................................................................................500
# ....................................................................................................600
# ...

# %%
run rep.py -2
# Out:
# repcol=#1f77b4
# minx=99,miny=-1.1671332560366114
# minstdx,y=20,-0.10993508893237618
# repcol=#ff7f0e
# minx=42,miny=-3.2394164756825097
# minstdx,y=82,-3.18519002507664
# imgfile=datadir/20230313_061949/report.png

# %%
run fluid.py -tr
# Out:
# COMPUTING DEVICE: cuda:0
# {'ROUND': 1, 'MODEL_ID': 1001, 'INIT_LR': 0.01, 'BATCHSIZE': 1, 'NUM_EPOCHS': 100, 'NUM_META_EPOCS': 1, 'ITERS': 1.1, 'SCRAMBLE_SIZE': 1, 'LAYER': [{'NCHAN': 5, 'KSIZE': 3, 'LEAK': 0.5, 'DROPOUT': 0.1}, {'NCHAN': 1, 'KSIZE': 5, 'LEAK': 0.5, 'DROPOUT': 0.0}], 'LAYER_LAST': {'KSIZE': 1, 'LEAK': 0.0, 'DROPOUT': 0.2}}
# LOADING DATA
# ....................................................................................................100
# ....................................................................................................200
# ....................................................................................................300
# ....................................................................................................400
# ....................................................................................................500
# ....................................................................................................600
# ...

# %%
cv2.destroyAllWindows()

# %%
os.path.dirname(".")
# Out:
# ''

# %%
os.path.basename(os.path.realpath("."))
# Out:
# 'torchfluid'

# %%
run fluids.py -evolve
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/micromamba/envs/oldcuda90/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# ~/micromamba/envs/oldcuda90/lib/python3.7/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'fluids.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_157885/268569954.py in <module>
# ----> 1 get_ipython().run_line_magic('run', 'fluids.py -evolve')
#
# ...

# %%
pwd
# Out:
# '/home/tomh/torchfluid'

# %%
run fluid.py -evolve
# Out:
# COMPUTING DEVICE: cuda:0
# agents found = 845
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# (100, 5)
# ...

# %%
argindex
# Out:
# array([480, 221, 747, 417, 444, 682, 416, 155, 135, 397, 291, 843, 138,
#        199, 238, 818, 134, 564, 133, 609,  14, 324,  83, 436, 556, 574,
#        151, 760, 441, 699, 252,  94, 312, 737, 811, 542, 704, 482, 643,
#         88, 207, 657,  70, 356, 377, 449,  79, 553, 364,  98, 175, 332,
#        208, 385, 763,  81, 494, 598, 831, 582, 681,  49, 424, 773, 511,
#        644, 820, 334, 461, 593, 172, 123, 495, 307, 239, 569, 772, 802,
#        389, 795, 233, 565, 386,  39, 164, 548, 775, 471, 707, 168, 373,
#        129, 676, 783, 149, 443, 260, 142, 524, 399, 720,  35, 739,  13,
#        518, 510,  33, 655, 666,  32, 567, 778, 348,  37, 573, 546, 463,
#        395, 619, 439, 153, 354, 697, 836, 105, 639, 741, 147, 686,  72,
#         75, 145,  53, 638, 640, 717, 206, 538,  99, 724, 280, 367, 220,
#        634, 626,  59,   5, 473, 469,  61, 360,  38, 181, 412, 108, 177,
#         20, 205,  69, 646, 633, 457, 330, 782, 447, 309, 520, 571, 561,
# ...

# %%
agents
# Out:
# ['datadir/20230313_015936/model_params.json',
#  'datadir/20230313_032525/model_params.json',
#  'datadir/20230313_013354/model_params.json',
#  'datadir/20230313_030318/model_params.json',
#  'datadir/20230313_014623/model_params.json',
#  'datadir/20230313_021057/model_params.json',
#  'datadir/20230313_030246/model_params.json',
#  'datadir/20230313_030604/model_params.json',
#  'datadir/20230313_032021/model_params.json',
#  'datadir/20230313_023620/model_params.json',
#  'datadir/20230313_023930/model_params.json',
#  'datadir/20230313_013202/model_params.json',
#  'datadir/20230313_034841/model_params.json',
#  'datadir/20230313_033129/model_params.json',
#  'datadir/20230313_012738/model_params.json',
#  'datadir/20230313_025339/model_params.json',
#  'datadir/20230313_023900/model_params.json',
#  'datadir/20230313_021253/model_params.json',
#  'datadir/20230313_013141/model_params.json',
#  'datadir/20230313_020404/model_params.json',
# ...
