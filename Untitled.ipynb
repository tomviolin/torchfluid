# %%
run rep.py -3
# Out:
# repcol=#1f77b4
# repcol=#ff7f0e
# repcol=#2ca02c
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# File ~/torchfluid/rep.py:30
#      28 coli+=1
#      29 print(f"repcol={repcol}")
# ---> 30 x=pd.read_csv(reps,header=None)
#      31 yvals=np.log(x.iloc[:,-1]+0.1)
#      32 plt.plot(range(xcoord,xcoord+len(yvals)),yvals,label=reps[-6:], color=repcol,alpha=0.4)
#
# File ~/torchfluid/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/torchfluid/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
